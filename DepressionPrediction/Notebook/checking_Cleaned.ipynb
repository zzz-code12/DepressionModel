# %% [markdown]
# Checking the cleaned dataset
#
# #Nag check lang ako dito kung clean na ba yung data set na gamit ko

# %%
import pandas as pd

df_cleaned = pd.read_csv(r'C:\Users\Zen\OneDrive\Desktop\DepressionPrediction\Notebook\cleaned_depression_data.csv')

# basic check
print("=" * 50)
print("SHAPE")
print("=" * 50)
print(df_cleaned.shape)

print("\n" + "=" * 50)
print("COLUMNS")
print("=" * 50)
print(df_cleaned.columns.tolist())

print("\n" + "=" * 50)
print("FIRST 5 ROWS")
print("=" * 50)
print(df_cleaned.head())

print("\n" + "=" * 50)
print("MISSING VALUES")
print("=" * 50)
print(df_cleaned.isnull().sum())

print("\n" + "=" * 50)
print("DATA TYPES")
print("=" * 50)
print(df_cleaned.dtypes)
# Out:
# ...
# SHAPE
# ...
# (27790, 12)
#
# ...
# COLUMNS
# ...
# ['Gender', 'Academic Pressure', 'CGPA', 'Study Satisfaction', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness', 'Depression']
#
# ...
# FIRST 5 ROWS
# ...
#    Gender  Academic Pressure  CGPA  Study Satisfaction  Sleep Duration  \
# 0       1                  5  8.97                   2               2
# 1       0                  2  5.90                   5               2
# 2       1                  3  7.03                   5               1
# 3       0                  3  5.59                   2               3
# 4       0                  4  8.13                   3               2
#
#    Dietary Habits  Degree  Have you ever had suicidal thoughts ?  \
# 0               3       1                                      1
# 1               2       1                                      0
# ...
